# %%
from skimage import data, io, filters

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
import random

# %%
i = Image.open('sample.jpg')

# %%
i
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=620x465 at 0x160E2588>

# %%
i = i.convert('L')

# %%
edges = filters.sobel(i)

# %%
np.asarray(i)
# Out:
# array([[108, 107, 103, ...,  66,  66,  66],
#        [105, 105, 103, ...,  69,  69,  69],
#        [101, 103, 103, ...,  65,  65,  65],
#        ...,
#        [119, 120, 120, ..., 140, 140, 140],
#        [120, 120, 120, ..., 139, 140, 139],
#        [118, 118, 118, ..., 141,  56,  54]], dtype=uint8)

# %%
edges
# Out:
# array([[ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ],
#        [ 0.        ,  0.0114752 ,  0.01180548, ...,  0.00277297,
#          0.00277297,  0.        ],
#        [ 0.        ,  0.00876889,  0.00693242, ...,  0.01734491,
#          0.01663781,  0.        ],
#        ...,
#        [ 0.        ,  0.00713736,  0.00219222, ...,  0.00138648,
#          0.00138648,  0.        ],
#        [ 0.        ,  0.00490196,  0.00490196, ...,  0.07941176,
#          0.1854704 ,  0.        ],
#        [ 0.        ,  0.        ,  0.        , ...,  0.        ,
#          0.        ,  0.        ]])

# %%
plt.imshow(edges)
plt.show()

# %%
io.imshow(edges)
# Out:
# C:\Users\Ashwin\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "

# %%
plt.show()

# %%
np.shape(i)
# Out:
# (465, 620)

# %%
np.shape(edges)
# Out:
# (465, 620)

# %%
len(edges)
# Out:
# 465

# %%
type(edges)
# Out:
# numpy.ndarray

# %%
l = 0
t = []

# %%
for i in edges:
    for j in i:
        if j >0.10 and j <0.15:
            l = l + 1
            t.append(np.asarray(j))
            #print(j)
        else:
            t.append(np.asarray(0))

# %%
l
# Out:
# 597

# %%
465*620
# Out:
# 288300

# %%
len(t)
# Out:
# 288300

# %%
t = np.asarray(t)

# %%
type(t)
# Out:
# numpy.ndarray

# %%
np.shape(t)
# Out:
# (288300,)

# %%
t=t.reshape(465,620)

# %%
t.sum()
# Out:
# 72.946156665846473

# %%
image = Image.fromarray(t)

# %%
io.imshow(t)
# Out:
# C:\Users\Ashwin\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "

# %%
plt.show()

# %%
ind = list(enumerate(t))

# %%
len(t)
# Out:
# 465

# %%
l = 0
u = []

# %%
for i in edges:
    for j in i:
        if j >0.120 and j <0.125:
            l = l + 1
            u.append(np.asarray(1))
            #print(j)
        else:
            u.append(np.asarray(0))

# %%
np.shape(u)
# Out:
# (288300,)

# %%
u = np.asarray(u)

# %%
u = u.reshape(465,620)

# %%
u.sum()
# Out:
# 60

# %%
img = Image.fromarray(u)

# %%
io.imshow(u)
# Out:
# C:\Users\Ashwin\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "

# %%
plt.show()

# %%
k = list(enumerate(u))

# %%
len(k)
# Out:
# 465

# %%
nx = []
for i,j in k:
    if sum(j) != 0:
        print("{}-{}".format(i,sum(j)))
        nx.append(i)
# Out:
# 167-1
# 168-1
# 171-1
# 172-1
# 175-1
# 176-1
# 180-1
# 181-1
# 186-1
# 187-1
# 192-1
# 193-1
# 205-1
# 209-1
# 214-1
# 218-2
# 220-1
# 221-1
# 224-1
# 227-1
# 230-1
# 232-2
# 234-1
# 236-1
# 237-1
# 238-2
# 239-1
# 241-1
# 244-1
# 245-1
# 246-2
# 247-1
# 248-2
# 249-1
# 250-4
# 251-1
# 252-1
# 253-1
# 257-1
# 258-1
# 261-1
# 330-1
# 331-1
# 337-1
# 340-1
# 341-1
# 342-1
# 343-1
# 345-2
# 393-2

# %%
len(u[166])
# Out:
# 620

# %%
for j in range(0,100):
    try:
        points = []

        for i in range(0,3):
            x=random.choice(nx)

            ny = []
            for i,p in enumerate(u[x]):
                if p == 1:
                    print(i)
                    ny.append(i)

            y = random.choice(ny)

            a = [x,y]
            points.append(a)



        [x1,y1] = points[0]
        [x2,y2] = points[1]
        [x3,y3] = points[2]

        a123 = np.asarray([[x2**2+y2**2-(x1**2+y1**2),2*(y2-y1)],
                          [x3**2+y3**2-(x1**2+y1**2),2*(y3-y1)]])

        a = int(np.linalg.det(a123)/(4*((x2 - x1)*(y3-y1)-(x3-x1)*(y2-y1))))

        b123 = np.asarray([[2*(x2-x1),x2**2+y2**2-(x1**2+y1**2)],
                          [2*(x3-x1),x3**2+y3**2-(x1**2+y1**2)]])


        b = int(np.linalg.det(b123)/(4*((x2-x1)*(y3-y1)-(x3-x1)*(y2-y1))))

        r = int(np.sqrt((x1-a)**2 + (y1-b)**2))


        blank = np.zeros([465,620],dtype = np.uint8)

        m = 0
        n = 0
        for m in range(0,465):
            for n in range(0,620):
                dist = abs(np.sqrt((m-a)**2 + (n-b)**2) - r)
                if dist < 1:
                    blank[m][n] = 1

        io.imshow(blank)
        
        print([a,b,r])
        plt.show()
        del a, b, r
    except:
        pass
# Out:
# 280
# 140
# 141
# 289
# C:\Users\Ashwin\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "
# [230, 126, 163]
# 270
# 274
# 292
# [216, 314, 52]
# 345
# 287
# 266
# [207, 308, 42]
# 140
# 141
# 283
# 318
# [356, 327, 189]
# 276
# 274
# 318
# 320
# [233, 294, 26]
# 285
# 277
# 282
# 338
# [283, 304, 57]
# 249
# 293
# 273
# 281
# [583, -2341, 2644]
# 269
# 579
# 345
# [641, 342, 454]
# 276
# 274
# 345
# [235, 324, 52]
# 285
# 294
# 348
# [296, 345, 72]
# 326
# 283
# 273
# [206, 309, 44]
# 265
# 274
# 335
# [308, 420, 156]
# 335
# 269
# 281
# [205, 307, 40]
# 262
# 270
# 345
# [-119, -417, 820]
# 289
# 282
# 338
# 349
# [211, 310, 39]
# 348
# 335
# 327
# 328
# [208, 309, 42]
# 276
# 581
# 348
# [-10520, 1803, 10842]
# 282
# 338
# 317
# 279
# [177, 320, 71]
# 318
# 287
# 339
# [207, 307, 41]
# 265
# 318
# 320
# 273
# [281, 280, 52]
# ...

# %%
io.imshow(u)
plt.show()
# Out:
# C:\Users\Ashwin\Anaconda3\lib\site-packages\skimage\io\_plugins\matplotlib_plugin.py:74: UserWarning: Low image data range; displaying image with stretched contrast.
#   warn("Low image data range; displaying image with "
